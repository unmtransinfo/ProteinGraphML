# %%
from ProteinGraphML.DataAdapter import OlegDB
from ProteinGraphML.GraphTools import ProteinDiseaseAssociationGraph

# we will create a Protein Disease graph from the DB adapter 'OlegDB'

# %%
dbAdapter = OlegDB()

proteinGraph = ProteinDiseaseAssociationGraph(dbAdapter)

# we construct a base map of protein to disease just by creating the ProteinDiseaseAssociationGraph
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in wrap_dbapi_exceptions(func, provider, *args, **kwargs)
#      49         if provider.dialect != 'SQLite':
# ---> 50             return func(provider, *args, **kwargs)
#      51         else:
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in connect(provider)
#     214     def connect(provider):
# --> 215         return provider.pool.connect()
#     216
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in connect(pool)
#     335             is_new_connection = True
# --> 336             pool._connect()
#     337             pool.pid = pid
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbproviders/postgres.py in _connect(pool)
#     185     def _connect(pool):
# --> 186         pool.con = pool.dbapi_module.connect(*pool.args, **pool.kwargs)
#     187         if 'client_encoding' not in pool.kwargs:
#
# ~/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: could not translate host name "hostit" to address: Name or service not known
#
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-c1aa677b7a78> in <module>
# ----> 1 dbAdapter = OlegDB()
#       2
#       3 proteinGraph = ProteinDiseaseAssociationGraph(dbAdapter)
#       4
#       5 # we construct a base map of protein to disease just by creating the ProteinDiseaseAssociationGraph
#
# ~/Desktop/MetapathML/ProteinGraphML/DataAdapter/Adapter.py in __init__(self)
#      70
#      71         def __init__(self):
# ---> 72                 self.load()
#      73
#      74         def loadTotalProteinList(self):
#
# ~/Desktop/MetapathML/ProteinGraphML/DataAdapter/Adapter.py in load(self)
#     152
#     153                 self.db = Database()
# --> 154                 self.db.bind(provider='postgres',user=user,password=password,host=host,database=database)
#     155                 self.db.generate_mapping(create_tables=False)
#     156
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/core.py in bind(self, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/pony/utils/utils.py in cut_traceback(func, *args, **kwargs)
#      76             if module_name.startswith('pony.utils') and tb.tb_frame.f_code.co_name == 'throw':
#      77                 reraise(exc_type, exc, last_pony_tb)
# ---> 78             reraise(exc_type, exc, full_tb)
#      79         finally:
#      80             del exc, full_tb, tb, last_pony_tb
#
# ~/anaconda3/lib/python3.7/site-packages/pony/utils/utils.py in reraise(***failed resolving arguments***)
#      93 else:
#      94     def reraise(exc_type, exc, tb):
# ---> 95         try: raise exc.with_traceback(tb)
#      96         finally: del exc, tb
#      97
#
# ~/anaconda3/lib/python3.7/site-packages/pony/utils/utils.py in cut_traceback(func, *args, **kwargs)
#      59         return func(*args, **kwargs)
#      60
# ---> 61     try: return func(*args, **kwargs)
#      62     except AssertionError: raise
#      63     except Exception:
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/core.py in bind(self, *args, **kwargs)
#     763     @cut_traceback
#     764     def bind(self, *args, **kwargs):
# --> 765         self._bind(*args, **kwargs)
#     766     def _bind(self, *args, **kwargs):
#     767         # argument 'self' cannot be named 'database', because 'database' can be in kwargs
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/core.py in _bind(self, *args, **kwargs)
#     781             provider_cls = provider_module.provider_cls
#     782         kwargs['pony_call_on_connect'] = self.call_on_connect
# --> 783         self.provider = provider_cls(*args, **kwargs)
#     784     @property
#     785     def last_sql(database):
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in __init__(provider, *args, **kwargs)
#     113         if pool_mockup: provider.pool = pool_mockup
#     114         else: provider.pool = provider.get_pool(*args, **kwargs)
# --> 115         connection, is_new_connection = provider.connect()
#     116         if call_on_connect:
#     117             call_on_connect(connection)
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in connect(provider)
#
# ~/anaconda3/lib/python3.7/site-packages/pony/orm/dbapiprovider.py in wrap_dbapi_exceptions(func, provider, *args, **kwargs)
#      59     except dbapi_module.OperationalError as e:
#      60         if provider.dialect == 'SQLite': provider.restore_exception()
# ---> 61         raise OperationalError(e)
#      62     except dbapi_module.DataError as e: raise DataError(e)
#      63     except dbapi_module.DatabaseError as e: raise DatabaseError(e)
#
# OperationalError: could not translate host name "hostit" to address: Name or service not known

# %%
# the 'ProteinDiseaseAssociationGraph' object has helper methods, but we can also access the networkx graph directly it is created with:
proteinGraph.graph.nodes
# Out:
# NodeView(('MP_0000062', 3256, 'MP_0000124', 'MP_0000137', 'MP_0000149', 'MP_0000150', 'MP_0000154', 'MP_0000194', 'MP_0000367', 'MP_0000432', 'MP_0000438', 'MP_0000443', 'MP_0000452', 'MP_0000455', 'MP_0000458', 'MP_0000550', 'MP_0000552', 'MP_0000556', 'MP_0000558', 'MP_0000559', 'MP_0000562', 'MP_0000564', 'MP_0000572', 'MP_0000579', 'MP_0000588', 'MP_0000745', 'MP_0001258', 'MP_0001284', 'MP_0001289', 'MP_0001293', 'MP_0001303', 'MP_0001304', 'MP_0001307', 'MP_0001312', 'MP_0001314', 'MP_0001319', 'MP_0001322', 'MP_0001325', 'MP_0001340', 'MP_0001399', 'MP_0001402', 'MP_0001406', 'MP_0001410', 'MP_0001486', 'MP_0004599', 'MP_0001489', 'MP_0001510', 'MP_0001512', 'MP_0001513', 'MP_0001523', 'MP_0001529', 'MP_0001539', 'MP_0001556', 'MP_0001566', 'MP_0001925', 'MP_0001926', 'MP_0002060', 'MP_0002067', 'MP_0002075', 'MP_0002098', 'MP_0002100', 'MP_0002102', 'MP_0002110', 'MP_0002111', 'MP_0002187', 'MP_0002544', 'MP_0002546', 'MP_0002626', 'MP_0002757', 'MP_0002758', 'MP_0002764', 'MP_0002792', 'MP_0002834', 'MP_0002932', 'MP_0002942', 'MP_0003019', 'MP_0003313', 'MP_0003769', 'MP_0003795', 'MP_0003896', 'MP_0003900', 'MP_0003929', 'MP_0003960', 'MP_0004156', 'MP_0004222', 'MP_0004509', 'MP_0004609', 'MP_0004924', 'MP_0005102', 'MP_0005108', 'MP_0005176', 'MP_0005178', 'MP_0005270', 'MP_0005287', 'MP_0005293', 'MP_0005296', 'MP_0005298', 'MP_0005385', 'MP_0005542', 'MP_0005553', 'MP_0005560', 'MP_0005565', 'MP_0005568', 'MP_0005628', 'MP_0005632', 'MP_0005633', 'MP_0005655', 'MP_0006203', 'MP_0006241', 'MP_0006243', 'MP_0008259', 'MP_0009141', 'MP_0009198', 'MP_0009204', 'MP_0010024', 'MP_0010052', 'MP_0010097', 'MP_0010123', 'MP_0010124', 'MP_0010379', 'MP_0010393', 'MP_0010507', 'MP_0010571', 'MP_0011100', 'MP_0011239', 'MP_0011953', 'MP_0011967', 'MP_0011968', 'MP_0012000', 'MP_0013279', 'MP_0011396', 4318, 'MP_0000160', 'MP_0000161', 'MP_0000162', 'MP_0000186', 'MP_0000198', 'MP_0000218', 'MP_0000947', 'MP_0001364', 'MP_0001392', 'MP_0001417', 'MP_0001552', 'MP_0001554', 'MP_0002079', 'MP_0002590', 'MP_0002608', 'MP_0002644', 'MP_0002699', 'MP_0002702', 'MP_0002804', 'MP_0002833', 'MP_0002896', 'MP_0002965', 'MP_0002968', 'MP_0003036', 'MP_0003064', 'MP_0003131', 'MP_0004083', 'MP_0004151', 'MP_0004174', 'MP_0004613', 'MP_0005292', 'MP_0005343', 'MP_0005344', 'MP_0005505', 'MP_0005559', 'MP_0005561', 'MP_0005564', 'MP_0005567', 'MP_0005627', 'MP_0005642', 'MP_0006359', 'MP_0010053', 'MP_0010099', 'MP_0010392', 'MP_0010511', 'MP_0011275', 'MP_0011496', 'MP_0011954', 'MP_0012121', 'MP_0012122', 'MP_0013278', 3391, 'MP_0000183', 'MP_0000221', 'MP_0000565', 'MP_0001408', 'MP_0001413', 'MP_0001491', 'MP_0002073', 'MP_0002177', 'MP_0002599', 'MP_0003020', 'MP_0003442', 'MP_0005358', 'MP_0005562', 'MP_0005566', 'MP_0005634', 'MP_0005635', 'MP_0006358', 'MP_0008730', 'MP_0008806', 'MP_0008810', 'MP_0009931', 'MP_0010068', 'MP_0010087', 'MP_0010091', 'MP_0010093', 'MP_0010096', 'MP_0010102', 'MP_0010378', 'MP_0011941', 'MP_0001488', 'MP_0003233', 'MP_0009142', 'MP_0010570', 'MP_0011436', 'MP_0011471', 'MP_0001697', 3307, 'MP_0000063', 'MP_0000111', 'MP_0000195', 'MP_0000266', 'MP_0000269', 'MP_0000280', 'MP_0000288', 'MP_0000428', 'MP_0000433', 'MP_0000603', 'MP_0000783', 'MP_0000841', 'MP_0000897', 'MP_0000914', 'MP_0001297', 'MP_0001404', 'MP_0001575', 'MP_0001614', 'MP_0001672', 'MP_0001706', 'MP_0001718', 'MP_0001722', 'MP_0001785', 'MP_0001914', 'MP_0002080', 'MP_0002109', 'MP_0002574', 'MP_0002875', 'MP_0002953', 'MP_0003054', 'MP_0003179', 'MP_0003257', 'MP_0003385', 'MP_0003393', 'MP_0003717', 'MP_0003720', 'MP_0003743', 'MP_0003921', 'MP_0003928', 'MP_0003961', 'MP_0003984', 'MP_0004576', 'MP_0004848', 'MP_0005179', 'MP_0005333', 'MP_0005388', 'MP_0005419', 'MP_0005554', 'MP_0005641', 'MP_0005650', 'MP_0008797', 'MP_0008854', 'MP_0009263', 'MP_0009908', 'MP_0010090', 'MP_0010580', 'MP_0011495', 'MP_0011951', 'MP_0013293', 3359, 3360, 'MP_0000182', 'MP_0001191', 'MP_0001257', 'MP_0001260', 'MP_0001317', 'MP_0001324', 'MP_00 ...

# %%
# we will want to filter by the proteins we are interested in, this list comes from a DB adapter, but any set will do

proteins = dbAdapter.loadTotalProteinList().protein_id
filterByProteins = set(proteins) # NOTE this is just a list of protein IDS

# %%
'''
using .attach will add edges from a DB as defined by the adapter, 
with this method we can create a graph of data, which can itself be saved, prevents the need from 
rebuilding as we work on different diseases, perform analysis

# NOTE THIS CELL TAKES A FEW MINUTES #

'''
proteinGraph.attach(dbAdapter.loadPPI(filterByProteins))
proteinGraph.attach(dbAdapter.loadKegg(filterByProteins)) 
proteinGraph.attach(dbAdapter.loadReactome(filterByProteins)) 
proteinGraph.attach(dbAdapter.loadInterpro(filterByProteins))
proteinGraph.attach(dbAdapter.loadGo(filterByProteins))

#we've also filter by proteins we care about, in this case it is our original list

# %%
# networkx provides an api we can nodes from 
 #- here i exploit the unique features of each node to count them

keggNodes = [g for g in list(proteinGraph.graph.nodes) if isinstance(g,str) and g[0:3] == "hsa"] # compute node lists
reactome = [r for r in list(proteinGraph.graph.nodes) if isinstance(r,str) and r[0:2] == "R-"]
goNodes = [go for go in list(proteinGraph.graph.nodes) if isinstance(go,str) and go[0:3] == "GO:"]
interNodes = [inter for inter in list(proteinGraph.graph.nodes) if isinstance(inter,str) and inter[0:3] == "IPR"]

# we can get a count of the nodes in the current graph
print("KEGG",len(keggNodes))
print("REACT",len(reactome))
print("GO",len(goNodes))
print("INTERP",len(interNodes))
# Out:
# KEGG 320
# REACT 2130
# GO 17531
# INTERP 14244

# %%
# this will save our graph
proteinGraph.save("CURRENT_GRAPH")
